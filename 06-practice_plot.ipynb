# %%
#Categorical =>bar plot
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)
titani=sns.load_dataset("titanic")
titani
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Categorical =>bar plot
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)
titani=sns.load_dataset("titanic")
sns.catplot(x="sex",y="survived",hue="class",kind="bar",data=titani)
plt.show()

# %%
#Categorical =>countplots
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)
titanic=sns.load_dataset("titanic")
p1=sns.countplot(x="sex", hue="class", data=titanic)
p1.settitle("Plot for counting")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [3], line 7
#       5 titanic=sns.load_dataset("titanic")
#       6 p1=sns.countplot(x="sex", hue="class", data=titanic)
# ----> 7 p1.settitle("Plot for counting")
#       8 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'settitle'

# %%
#Contionous  =>scatter plot
 
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)
titanic=sns.load_dataset("titanic")
g=sns.FacetGrid(row="sex", hue="alone", data=titanic)
g=(g.map(plt.scatter,"age","fare" ).add_legend())
g.settitle("Plot for counting")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [4], line 9
#       7 g=sns.FacetGrid(row="sex", hue="alone", data=titanic)
#       8 g=(g.map(plt.scatter,"age","fare" ).add_legend())
# ----> 9 g.settitle("Plot for counting")
#      10 plt.show()
#
# AttributeError: 'FacetGrid' object has no attribute 'settitle'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)
titanic=sns.load_dataset("titanic")
p1=sns.countplot(x="who", hue="alone", data=titanic)
p1.settitle("Plot for counting")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [5], line 6
#       4 titanic=sns.load_dataset("titanic")
#       5 p1=sns.countplot(x="who", hue="alone", data=titanic)
# ----> 6 p1.settitle("Plot for counting")
#       7 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'settitle'

# %%
#data visualization
#step1:importing libraries
import seaborn as sns
import matplotlib.pyplot as plt

# step#3 set a theme
sns.set_theme(style="ticks",color_codes=True)

#step3:loading dataset
kashti=sns.load_dataset("titanic")
print(kashti)
# print(kashti.describe())    

# #step4:plot the basic graph one variables (count plot)
p=sns.countplot(x="sex" ,data=kashti)
#count plot categroical data

plt.show()

# #step5:plot the basic graph with two vqriables (count plot)
#hue mean colours
p=sns.countplot(x="sex" ,data=kashti,hue="class")
#count plot categroical data
plt.show()

#step6:plot the basic graph with two vqriables (count plot) with titles
p=sns.countplot(x="sex" ,data=kashti,hue="class")
#count plot categroical data
p.set_title("count plot fot titanic")
plt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
